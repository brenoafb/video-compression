# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from yuv_reader import read_yuv
from block_utils import *
from compression import *
from decompression import *

# %%
filename = 'foreman_qcif.yuv'
width = 176
height = 144
nframes = 10

# %%
frames = read_yuv(filename)[:nframes]
plt.imshow(frames[0])

# %%
block_size = 16
delta = 50
first_frame, residuals, motion_vectors = compress_sequence(frames, block_size, delta)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
plt.imshow(first_frame)

# %%
plt.imshow(residuals[4][0])

# %%
recovered = build_sequence(first_frame, residuals, motion_vectors, block_size)

# %%
plt.imshow(frames[-1])

# %%
plt.imshow(recovered[-1])
